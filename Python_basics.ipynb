# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanamssanju01-svg/Python-basics-/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("sanjana")
# Out:
# sanjana

# %%
name="sanjana"
year="2007"

print("Hella",name)
print(year)
# Out:
# Hella sanjana
# 2007

# %%
name="sanjana"
year="2007"

print(name+year)
# Out:
# sanjana2007

# %%
a=10
b=20

print("add",a+b)
print("sub",a-b)
print("mul",a*b)
print("div",a/b)
# Out:
# add 30
# sub -10
# mul 200
# div 0.5

# %%
A=input("Enter your name")
B=input("Enter your branch")

print ("Hello",A)
print ("My branch is",B)
# Out:
# Enter your nameSanju
# Enter your branchCSE
# Hello Sanju
# My branch is CSE

# %%
A=int(input("Enter your first number"))
B=int(input("Enter your second number"))

print(A)
print(B)
print(A+B)
# Out:
# Enter your first number20
# Enter your second number30
# 20
# 30
# 50

# %%
Age=int(input("Enter your Age:"))

if Age>=18:
   print("You can vote👍")

else:
     print("Come again next year🤟")
# Out:
# Enter your Age:18
# You can vote👍
