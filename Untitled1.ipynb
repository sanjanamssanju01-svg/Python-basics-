# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanamssanju01-svg/Python-basics-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
    print("hello world")

greet()
# Out:
# hello world

# %%
def greet(name):
    print("hello",name)

greet("sanjana")
greet("sahana")
# Out:
# hello sanjana
# hello sahana

# %%
def add(a,b):
    return a+b

result=add(5,2)
print(result)
# Out:
# 7
